# %% [markdown]
# # Fifth Order Cumulant Expansion Method:

# %% [markdown]
# #### Obtaining the analytic equations of motion (and print all the variables in the equations of motion):

# %%
using QuantumCumulants

# Building the Hilbert space:
(hil_a,hil_b,hil_c) = (FockSpace(:pump),FockSpace(:signal), FockSpace(:idler))
hilbert_space = hil_a ⊗ hil_b ⊗ hil_c

# Defining the operators with labels "a", "b" and "c" in pump, signal and idler subspaces respectively:
(oper_a,oper_b,oper_c)= (Destroy(hilbert_space,:a,1), Destroy(hilbert_space,:b,2), 
                               Destroy(hilbert_space,:c,3))

# Hamiltonian:
hami =im*oper_a*oper_b'*oper_c'-im*oper_a'*oper_b*oper_c

# Finds all the fifth-order operators:
relev_operators=find_operators(hilbert_space,5)

# Finds all the equations using the fifth order cumulant expansion:
eqns_motion_analy = meanfield(relev_operators, hami; order=5)

# Printing the variables associated with the equations of motion:
ll=range(1,length(eqns_motion_analy),step=1)
temp_table = fill("", 250)
for ii in ll
       temp_table[ii]="$ii: $(eqns_motion_analy[ii].lhs)"
       end
x=reshape(temp_table,(25,10))
Base.print_matrix(stdout, x)
# Out:
#  "1: ⟨a⟩"        "26: ⟨a*c*c⟩"      "51: ⟨a′*a*b*c′⟩"  "76: ⟨a*a*a*c⟩"     "101: ⟨b′*b′*b′*b⟩"   "126: ⟨a*b*b*c*c⟩"     "151: ⟨a*b*b*b*c′⟩"    "176: ⟨a*b′*c*c*c⟩"     "201: ⟨a*b′*b′*b′*b′⟩"  "226: ⟨b′*b′*b′*b′*b⟩"
#  "2: ⟨b⟩"        "27: ⟨a′*a′*a⟩"    "52: ⟨a′*a*b*b⟩"   "77: ⟨a*c′*c*c⟩"    "102: ⟨b*b*c′*c′⟩"    "127: ⟨a*b′*b*b*c⟩"    "152: ⟨a*b*c′*c′*c′⟩"  "177: ⟨a*b′*b′*b′*c⟩"   "202: ⟨a*a*a*c′*c′⟩"    "227: ⟨b*b*b*c′*c′⟩"
#  "3: ⟨c⟩"        "28: ⟨a*b′*c′⟩"    "53: ⟨a′*a′*a*b⟩"  "78: ⟨a*c*c*c⟩"     "103: ⟨b*b*b*c′⟩"     "128: ⟨a*b*b*b*c⟩"     "153: ⟨a′*a*a*b*b⟩"    "178: ⟨a*a*c′*c′*c⟩"    "203: ⟨a*a*c′*c′*c′⟩"   "228: ⟨b*b*c′*c′*c′⟩"
#  "4: ⟨a*b⟩"      "29: ⟨a*a*b′⟩"     "54: ⟨a*b′*b*c′⟩"  "79: ⟨a′*a′*a′*a⟩"  "104: ⟨b*c′*c′*c′⟩"   "129: ⟨a*b*c′*c*c⟩"    "154: ⟨a*a*b′*b*b⟩"    "179: ⟨a*a*a*c′*c⟩"     "204: ⟨a*a*a*a*c′⟩"     "229: ⟨b*b*b*b*c′⟩"
#  "5: ⟨a*c⟩"      "30: ⟨a*b′*b′⟩"    "55: ⟨a*a*b′*b⟩"   "80: ⟨a*a*b′*c′⟩"   "105: ⟨b′*b′*b*b⟩"    "130: ⟨a*b*c*c*c⟩"     "155: ⟨a*a*a*b*b⟩"     "180: ⟨a*c′*c′*c′*c⟩"   "205: ⟨a*c′*c′*c′*c′⟩"  "230: ⟨b*c′*c′*c′*c′⟩"
#  "6: ⟨a′*a⟩"     "31: ⟨a*a*c′⟩"     "56: ⟨a*b′*b′*b⟩"  "81: ⟨a*b′*b′*c′⟩"  "106: ⟨b*b*b*b⟩"      "131: ⟨a′*a′*a*b′*b⟩"  "156: ⟨a*a*b*b*b⟩"     "181: ⟨a′*a*a*c*c⟩"     "206: ⟨a′*a′*a′*a*a⟩"   "231: ⟨b′*b′*b′*b*b⟩"
#  "7: ⟨a*b′⟩"     "32: ⟨a*c′*c′⟩"    "57: ⟨a*a*b*c′⟩"   "82: ⟨a*b′*c′*c′⟩"  "107: ⟨c′*c′*c′*c⟩"   "132: ⟨a′*a*b′*b′*b⟩"  "157: ⟨a′*a′*a*a*b⟩"   "182: ⟨a*a*c′*c*c⟩"     "207: ⟨a*a*a*a*a⟩"      "232: ⟨b*b*b*b*b⟩"
#  "8: ⟨a*c′⟩"     "33: ⟨a*a*a⟩"      "58: ⟨a*b*b*c′⟩"   "83: ⟨a*a*b′*b′⟩"   "108: ⟨c′*c′*c*c⟩"    "133: ⟨a′*a*b*b*c′⟩"   "158: ⟨a′*a*a*a*b⟩"    "183: ⟨a*a*a*c*c⟩"      "208: ⟨b′*b′*b*c′*c⟩"   "233: ⟨c′*c′*c′*c′*c⟩"
#  "9: ⟨a*a⟩"      "34: ⟨b′*b*c⟩"     "59: ⟨a*b*c′*c′⟩"  "84: ⟨a*a*a*b′⟩"    "109: ⟨c*c*c*c⟩"      "134: ⟨a′*a′*a*b*c′⟩"  "159: ⟨a*a*a*a*b⟩"     "184: ⟨a*a*c*c*c⟩"      "209: ⟨b′*b*c′*c′*c⟩"   "234: ⟨c′*c′*c′*c*c⟩"
#  "10: ⟨b*c⟩"     "35: ⟨b*c′*c⟩"     "60: ⟨a*a*b*b⟩"    "85: ⟨a*b′*b′*b′⟩"  "110: ⟨a′*a*b′*b*c⟩"  "135: ⟨a′*a*b*c′*c′⟩"  "160: ⟨a*b′*b′*b*b⟩"   "185: ⟨a′*a′*a*a*c⟩"    "210: ⟨b′*b′*b*c*c⟩"    "235: ⟨c*c*c*c*c⟩"
#  "11: ⟨b′*b⟩"    "36: ⟨b*b*c⟩"      "61: ⟨a′*a*a*b⟩"   "86: ⟨a*a*c′*c′⟩"   "111: ⟨a′*a*b*c′*c⟩"  "136: ⟨a′*a′*a*b*b⟩"   "161: ⟨a*b′*b*b*b⟩"    "186: ⟨a′*a*a*a*c⟩"     "211: ⟨b′*b*c*c*c⟩"     ""
#  "12: ⟨b*c′⟩"    "37: ⟨b*c*c⟩"      "62: ⟨a*a*a*b⟩"    "87: ⟨a*a*a*c′⟩"    "112: ⟨a′*a*b*b*c⟩"   "137: ⟨a′*a*b*b*b⟩"    "162: ⟨a*b*b*b*b⟩"     "187: ⟨a*a*a*a*c⟩"      "212: ⟨b′*b′*b′*b*c⟩"   ""
#  "13: ⟨b*b⟩"     "38: ⟨b′*b′*b⟩"    "63: ⟨a*b′*b*b⟩"   "88: ⟨a*c′*c′*c′⟩"  "113: ⟨a′*a*b*c*c⟩"   "138: ⟨a′*a′*a′*a*b⟩"  "163: ⟨a′*a′*a*c′*c⟩"  "188: ⟨a*c′*c′*c*c⟩"    "213: ⟨b*b*c′*c′*c⟩"    ""
#  "14: ⟨c′*c⟩"    "39: ⟨b*b*c′⟩"     "64: ⟨a*b*b*b⟩"    "89: ⟨a′*a′*a*a⟩"   "114: ⟨a′*a′*a*b*c⟩"  "139: ⟨a*a*b′*b*c′⟩"   "164: ⟨a′*a*c′*c′*c⟩"  "189: ⟨a*c′*c*c*c⟩"     "214: ⟨b*b*b*c′*c⟩"     ""
#  "15: ⟨c*c⟩"     "40: ⟨b*c′*c′⟩"    "65: ⟨a′*a*c′*c⟩"  "90: ⟨a*a*a*a⟩"     "115: ⟨a*b′*b*c′*c⟩"  "140: ⟨a*b′*b′*b*c′⟩"  "165: ⟨a′*a′*a*c*c⟩"   "190: ⟨a*c*c*c*c⟩"      "215: ⟨b*c′*c′*c′*c⟩"   ""
#  "16: ⟨a*b*c⟩"   "41: ⟨b*b*b⟩"      "66: ⟨a′*a*c*c⟩"   "91: ⟨b′*b*c′*c⟩"   "116: ⟨a*a*b′*b*c⟩"   "141: ⟨a*b′*b*c′*c′⟩"  "166: ⟨a′*a*c*c*c⟩"    "191: ⟨a′*a′*a′*a′*a⟩"  "216: ⟨b′*b*b*c*c⟩"     ""
#  "17: ⟨a′*a*b⟩"  "42: ⟨c′*c′*c⟩"    "67: ⟨a′*a′*a*c⟩"  "92: ⟨b′*b*c*c⟩"    "117: ⟨a*b′*b*c*c⟩"   "142: ⟨a*a*b′*b′*b⟩"   "167: ⟨a′*a′*a′*a*c⟩"  "192: ⟨a*a*b′*b′*c′⟩"   "217: ⟨b*b*c′*c*c⟩"     ""
#  "18: ⟨a*b′*b⟩"  "43: ⟨c*c*c⟩"      "68: ⟨a*b′*c′*c⟩"  "93: ⟨b′*b′*b*c⟩"   "118: ⟨a*b′*b′*b*c⟩"  "143: ⟨a*a*a*b′*b⟩"    "168: ⟨a*a*b′*c′*c⟩"   "193: ⟨a*a*b′*c′*c′⟩"   "218: ⟨b*b*b*c*c⟩"      ""
#  "19: ⟨a*b*c′⟩"  "44: ⟨a′*a*b*c⟩"   "69: ⟨a*a*b′*c⟩"   "94: ⟨b*b*c′*c⟩"    "119: ⟨a*a*b*c′*c⟩"   "144: ⟨a*b′*b′*b′*b⟩"  "169: ⟨a*b′*b′*c′*c⟩"  "194: ⟨a*a*a*b′*c′⟩"    "219: ⟨b*b*c*c*c⟩"      ""
#  "20: ⟨a*a*b⟩"   "45: ⟨a*b′*b*c⟩"   "70: ⟨a*b′*c*c⟩"   "95: ⟨b*c′*c′*c⟩"   "120: ⟨a*b*b*c′*c⟩"   "145: ⟨a*a*b*b*c′⟩"    "170: ⟨a*b′*c′*c′*c⟩"  "195: ⟨a*b′*b′*c′*c′⟩"  "220: ⟨b′*b′*b*b*c⟩"    ""
#  "21: ⟨a*b*b⟩"   "46: ⟨a*b*c′*c⟩"   "71: ⟨a*b′*b′*c⟩"  "96: ⟨b*b*c*c⟩"     "121: ⟨a*b*c′*c′*c⟩"  "146: ⟨a′*a*a*b*c′⟩"   "171: ⟨a*a*b′*c*c⟩"    "196: ⟨a*b′*b′*b′*c′⟩"  "221: ⟨b′*b*b*b*c⟩"     ""
#  "22: ⟨a′*a*c⟩"  "47: ⟨a*a*b*c⟩"    "72: ⟨a*a*c′*c⟩"   "97: ⟨b′*b*b*c⟩"    "122: ⟨a*a*b*b*c⟩"    "147: ⟨a*a*b*c′*c′⟩"   "172: ⟨a*a*b′*b′*c⟩"   "197: ⟨a*b′*c′*c′*c′⟩"  "222: ⟨b*b*b*b*c⟩"      ""
#  "23: ⟨a*b′*c⟩"  "48: ⟨a*b*b*c⟩"    "73: ⟨a*c′*c′*c⟩"  "98: ⟨b*b*b*c⟩"     "123: ⟨a*a*b*c*c⟩"    "148: ⟨a*a*a*b*c′⟩"    "173: ⟨a*a*a*b′*c⟩"    "198: ⟨a*a*a*b′*b′⟩"    "223: ⟨b*c′*c′*c*c⟩"    ""
#  "24: ⟨a*c′*c⟩"  "49: ⟨a*b*c*c⟩"    "74: ⟨a*a*c*c⟩"    "99: ⟨b*c′*c*c⟩"    "124: ⟨a′*a*a*b*c⟩"   "149: ⟨a*b′*b*b*c′⟩"   "174: ⟨a*b′*b′*c*c⟩"   "199: ⟨a*a*b′*b′*b′⟩"   "224: ⟨b*c′*c*c*c⟩"     ""
#  "25: ⟨a*a*c⟩"   "50: ⟨a′*a*b′*b⟩"  "75: ⟨a′*a*a*c⟩"   "100: ⟨b*c*c*c⟩"    "125: ⟨a*a*a*b*c⟩"    "150: ⟨a*b*b*c′*c′⟩"   "175: ⟨a*b′*c′*c*c⟩"   "200: ⟨a*a*a*a*b′⟩"     "225: ⟨b*c*c*c*c⟩"      ""

# %% [markdown]
# #### Setting up parameters and solving the ODE:

# %%
using ModelingToolkit
using OrdinaryDiffEq

ALP_SQ = 100  # alpha square
ALP=sqrt(ALP_SQ) ## alpha

# Setting up the time array for evolution:
T_END = 0.380 # Total time of the evolution
DELT_T = 0.001 # Time step for the evolution
t_arr = LinRange(0, T_END,round(Int, T_END / DELT_T) + 1);
################################################################################
# Equations of motion become unstable at longer times, so noting those times
# when they become unstable:
#DELT_T=0.001 and T_END=0.380 for ALP_SQ=sqrt(100)
#DELT_T=0.001 and T_END=0.332 for ALP_SQ=sqrt(163) 
#DELT_T=0.001 and T_END=0.270 for ALP_SQ=sqrt(268)
#DELT_T=0.001 and T_END=0.220 for ALP_SQ=sqrt(439) 
#DELT_T=0.001 and T_END=0.178 for ALP_SQ=sqrt(719) 
#DELT_T=0.0005 and T_END=0.156 for ALP_SQ=sqrt(1000) 
###############################################################################

# Initial conditions for the ODE:
sol_ini = zeros(ComplexF64,235)
sol_ini[1]=ALP
sol_ini[6]=ALP_SQ
sol_ini[9]=ALP_SQ
sol_ini[27]=ALP^3
sol_ini[33]=ALP^3
sol_ini[79]=ALP^4
sol_ini[89]=ALP^4
sol_ini[90]=ALP^4
sol_ini[191]=ALP^5
sol_ini[206]=ALP^5
sol_ini[207]=ALP^5

# Solving the ODEs:
@named system_eqns = ODESystem(eqns_motion_analy)
problem = ODEProblem(system_eqns,sol_ini,(0.0,last(t_arr)));
sol = solve(problem,Tsit5(),abstol=1e-16,reltol=1e-16, saveat = t_arr);

# %% [markdown]
# #### 1. Plotting the populations:

# %%
using Plots
plot([0, last(t_arr)], [ALP_SQ, ALP_SQ],ls=:dash,color=:red,label="(α₀)²= $ALP_SQ")
plot!(sol.t,real.(sol[oper_a'*oper_a]),label="Pump Population",color=3)
plot!(sol.t,real.(sol[oper_b'*oper_b]),xlabel="Time, τ",label="Signal Population",legend=:left,color=2)

# %% [markdown]
# #### 2. Plotting the pump variance:

# %%
## Eq. C12 in the manuscript:
deltsq_pump_momtm= real.(0.5 .+ sol[oper_a'*oper_a] .- sol[oper_a*oper_a])

plot([0, last(t_arr)], [0.5, 0.5],ls=:dash,color=:red,label="1/2")
plot!(sol.t,deltsq_pump_momtm,label="",xlabel="Time, τ",
                                 ylabel="Pump mode variance, (ΔPₚᵤₘₚ)²",ylims=(-0.1,0.6),color=1)
plot!([0, last(t_arr)], [0.0, 0.0],ls=:dash,color=:black,label="")

# %% [markdown]
# #### 3. Zero-delay autocorrelation function:

# %%
pump_g2= real.((sol[oper_a'*oper_a'*oper_a*oper_a]) ./ (sol[oper_a'*oper_a].^2))
sig_g2= real.((sol[oper_b'*oper_b'*oper_b*oper_b]) ./ (sol[oper_b'*oper_b].^2))
sig_g2[1]=2;

using Plots
plot(sol.t,pump_g2,label="gₚ⁽²⁾",color=3)
plot!(sol.t,sig_g2,label="gₛ⁽²⁾",xlabel="Time, τ", ylabel="Zero-time autocorrelation"
                                                          ,color=2)

# %% [markdown]
# #### 4. Exporting all the data (run only if required):

# %%
# For writing the data:

#using NPZ
#npzwrite("Cumulant_$(ALP_SQ)_alpha_squared_level5.npy", 
#Dict("time" => sol.t, "pump_population" => real.(sol[oper_a'*oper_a]),
#"signal_population" => real.(sol[oper_b'*oper_b]),"pump_variance_momentum" => deltsq_pump_momtm,
#"pump_g2" => pump_g2, "sig_g2" => sig_g2))
